# %%
import pandas as pd
import scanpy as sc

# %%
scvi=sc.read_h5ad("ribas/NSCL/NSCL_5p_SCVI_MERGED.h5")
scano=sc.read_h5ad("ribas/NSCL/NSCL_5p_SCANORAMA.h5")

# %%
for i in range(len(scvi.obs_names)):
    if scvi.obs_names[i]!=scano.obs_names[i]:
        print("alksdalsdkjf")

# %%
scano.obs_names
# Out:
# Index(['GTTCGGGCAGTACACT-1-0', 'CTCCTAGTCTTGACGA-1-0', 'GTAACGTCAATGGAGC-1-0',
#        'TTCGAAGTCATGCAAC-1-0', 'TGAGGGAGTTACCGAT-1-0', 'ATCGAGTTCAAACGGG-1-0',
#        'CTCACACCACGGATAG-1-0', 'TATCTCACACCACGTG-1-0', 'TGTCCCAAGTTTCCTT-1-0',
#        'AGATCTGTCACCTTAT-1-0',
#        ...
#        'TGCACCTCAGGGTATG-1-3', 'ACGGAGAGTTGACGTT-1-3', 'TATCAGGAGCCGTCGT-1-3',
#        'GCTTCCAAGTACGATA-1-3', 'AACTCCCCAAACAACA-1-3', 'CTCGAAACACATTTCT-1-3',
#        'TTCTTAGAGGTAAACT-1-3', 'GAACATCAGACTCGGA-1-3', 'AGAGCGACAGGTGGAT-1-3',
#        'AGAGCGATCAAAGACA-1-3'],
#       dtype='object', length=19136)

# %%
bi005={
    0:'Neuronal',
    1:'T-cell',
    2:'Neuronal',
    3:'Mixed bag',
    4:'Myeloid',
    5:'Neuronal',
    6:'Mitochondrial',
    7:'Myeloid',
    8:'Neuronal / Stromal',
    9:'Stromal',
    10:'T-cell / NK cells',
    11:'Stromal',
    12:'T-cell / NK cells',
    13:'Neuronal / Tumour',
    14:'Myeloid',
    15:'T-cell',
    16:'Mitochondrial',
    17:'Stromal',
    18:'B cells / Plasma cells',
    19:'Cycling neuronal',
    20:'Osteoclasts',
    21:'Myeloid',
    22:'Cycling neuronal',
    23:'B cells / Plasma cells',
    24:'T-cell',
    25:'Immune (mixed)',
    26:'Immune (mixed) / De-differentiated cells'
}

biad=pd.read_csv('ribas/DEGs/bi005_clusters')

celltypes=[bi005[i] for i in biad["PhenoGraph_clusters"]]

pd.DataFrame(celltypes).to_csv("ribas/DEGs/bi005_annotations")

# %%
bi005={
    0:'Mixed bag',
    1:'?',
    2:'?',
    3:'?',
    4:'Epithelial / Neuronal',
    5:'Mixed bag',
    6:'Myeloid',
    7:'Hepatocytes',
    8:'T-cell / NK',
    9:'B-cells / Plasma cells',
    10:'B-cells / Plasma cells',
    11:'Stromal',
    12:'B-cells / Plasma cells',
    13:'?',
    14:'Mixed bag',
    15:'Epithelial',
    16:'Myeloid',
    17:'Mixed bag',
    18:'Myeloid',
    19:'Mixed bag',
    20:'Neuronal',
    21:'Immune (mixed)',
    22:'Mitochondrial',
    23:'T-cell',
    24:'Mixed bag'
}

biad=pd.read_csv('ribas/DEGs/NSCL_5p_clusters')

celltypes=[bi005[i] for i in biad["PhenoGraph_clusters"]]

pd.DataFrame(celltypes).to_csv("ribas/DEGs/NSCL_5p_annotations")

# %%
bi005={
    0:'Neuronal',
    1:'Mixed bag',
    2:'Epithelial',
    3:'Epithelial / Neuronal',
    4:'Mixed bag',
    5:'Neuronal',
    6:'De-differentiated cells',
    7:'Stromal',
    8:'Cycling neuronal / de-differentiated cells / tumour cells',
    9:'Smooth muscle',
    10:'Myeloid',
    11:'Mixed bag',
    12:'B-cell / Plasma cell',
    13:'T-cell / NK',
    14:'Mixed bag',
    15:'?',
    16:'Immune (mixed)',
    17:'Mixed bag',
    18:'De-differentiated cells',
    19:'Mixed bag',
    20:'Mixed bag',
    21:'B-cell / Plasma cell',
    22:'Myeloid',
    23:'T-cell / NK',
    24:'Mixed bag',
    25:'Mixed bag',
    26:'Mixed bag',
    27:'Cell cycle / mitochondria'
}

biad=pd.read_csv('ribas/DEGs/NSCL_full_clusters')

celltypes=[bi005[i] for i in biad["PhenoGraph_clusters"]]

pd.DataFrame(celltypes).to_csv("ribas/DEGs/NSCL_full_annotations")

# %%
bi005={
    0:'Mixed bag',
    1:'De-differentiated',
    2:'T-cell / NK cell',
    3:'Myeloid',
    4:'Neuronal',
    5:'Neuronal / de-differentiated',
    6:'Mixed bag',
    7:'Myeloid',
    8:'Mixed bag',
    9:'T-cell / NK cell',
    10:'Cycling cells',
    11:'Mixed bag',
    12:'Fibroblasts',
    13:'T-cell / NK cell',
    14:'T-cell / NK cell',
    15:'Mixed bag',
    16:'T-cell / NK cell',
    17:'Mixed bag',
    18:'T-cell / NK cell',
    19:'Mixed bag',
    20:'Myeloid',
    21:'Epithelial',
    22:'Mixed bag',
    23:'Myeloid',
    24:'Myeloid',
    25:'Myeloid',
    26:'Immune (mixed)',
    27:'Myeloid',
    28:'Mixed bag',
    29:'Cycling Neuronal'
}

biad=pd.read_csv('ribas/DEGs/Sarcoma_clusters')

celltypes=[bi005[i] for i in biad["PhenoGraph_clusters"]]

pd.DataFrame(celltypes).to_csv("ribas/DEGs/Sarcoma_annotations")

# %%
bi005={
    0:'De-differentiated / Mitochondrial',
    1:'T-cell',
    2:'Cycling neuronal',
    3:'Cycling cells',
    4:'Mixed bag',
    5:'Mixed bag',
    6:'Myeloid',
    7:'Mitochondrial',
    8:'T-cell',
    9:'Mixed bag',
    10:'De-differentiated / Mitochondrial',
    11:'T-cell',
    12:'Mitochondrial',
    13:'Myeloid',
    14:'Myeloid',
    15:'Mitochondrial',
    16:'Neuronal / De-differentiated / T-cell',
    17:'T-cell',
    18:'T-cell',
    19:'Mixed bag',
    20:'Immune (mixed)',
    21:'Mixed bag',
    22:'Neuronal / De-differentiated'
}

biad=pd.read_csv('ribas/DEGs/UMEL_clusters')

celltypes=[bi005[i] for i in biad["PhenoGraph_clusters"]]

pd.DataFrame(celltypes).to_csv("ribas/DEGs/UMEL_annotations")
